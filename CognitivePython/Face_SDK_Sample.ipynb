# %% [markdown]
# # Using Cognitive Services Face API
#
# This example shows how to install and use Face API in Azure Notebook

# %%
# !pip install cognitive_face
# Out:
# ...
# done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/ef/0c/8f/14e0ac9bc5d2205ce7ae1a5401218c3425f0b2667cd3715e71
# Successfully built cognitive-face
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cognitive_face as CF

KEY = '1a9025a2ec4d43928e60f90cd5db6002'  # Replace with a valid Subscription Key here.
CF.Key.set(KEY)

img_url = 'https://raw.githubusercontent.com/Microsoft/Cognitive-Face-Windows/master/Data/detection1.jpg'
result = CF.face.detect(img_url,landmarks=True,attributes='age,gender,smile')
print result
# Out:
# [{u'faceId': u'b3b5ab73-766e-4676-abb2-d40cd85e3a60', u'faceRectangle': {u'width': 89, u'top': 66, u'height': 89, u'left': 446}, u'faceAttributes': {u'smile': 0.235, u'age': 23.3, u'gender': u'female'}, u'faceLandmarks': {u'underLipTop': {u'y': 137.6, u'x': 489.7}, u'noseTip': {u'y': 112.7, u'x': 499.5}, u'upperLipBottom': {u'y': 131.4, u'x': 491.1}, u'noseLeftAlarTop': {u'y': 106.9, u'x': 487.4}, u'eyebrowLeftOuter': {u'y': 75.8, u'x': 454.0}, u'eyeLeftBottom': {u'y': 92.2, u'x': 471.2}, u'pupilLeft': {u'y': 87.4, u'x': 473.0}, u'upperLipTop': {u'y': 127.9, u'x': 491.7}, u'eyeLeftInner': {u'y': 90.1, u'x': 478.8}, u'eyeRightInner': {u'y': 93.7, u'x': 502.3}, u'eyeLeftTop': {u'y': 83.3, u'x': 472.7}, u'mouthLeft': {u'y': 131.6, u'x': 468.2}, u'noseRightAlarTop': {u'y': 107.0, u'x': 502.1}, u'eyebrowRightInner': {u'y': 83.8, u'x': 506.0}, u'noseLeftAlarOutTip': {u'y': 115.5, u'x': 481.3}, u'noseRightAlarOutTip': {u'y': 116.1, u'x': 503.3}, u'noseRootRight': {u'y': 93.8, u'x': 499.9}, 
# ...
